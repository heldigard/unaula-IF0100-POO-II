# %% [markdown]
# # Clase 5.5 - Proyecto Final E6
#
# **Unidad:** 5 - Arquitectura de Datos Desconectados
# **Fecha:** Jueves 28 de Mayo de 2026
#
# ## Objetivos
#
# Demostrar dominio de:
# - POO en Python
# - FastAPI
# - SQLAlchemy ORM
# - Patrones de diseño
# - Clean Architecture

# %% [markdown]
# ---
#
# ## 1. Requisitos del Proyecto
#
# Desarrollar API REST para sistema de tareas/proyectos:
# - CRUD completo (2+ entidades relacionadas)
# - SQLAlchemy + SQLite
# - Arquitectura en capas
# - DTOs con Pydantic
# - Paginacion y filtros
# - Tests con pytest

# %% [markdown]
# ---
#
# ## 2. Estructura Requerida

# %%
print("""
proyecto/
├── app/
│   ├── main.py
│   ├── config.py
│   ├── domain/
│   │   ├── entities.py
│   │   └── repositories.py (ABC)
│   ├── infrastructure/
│   │   ├── database.py
│   │   ├── models.py (ORM)
│   │   └── repositories.py (Impl)
│   ├── application/
│   │   ├── services.py
│   │   └── dtos.py
│   └── interfaces/
│       └── controllers.py
├── tests/
│   ├── conftest.py
│   └── test_*.py
├── requirements.txt
└── README.md
""")

# %% [markdown]
# ---
#
# ## 3. Endpoints Requeridos

# %%
print("""
PROYECTOS:
GET    /api/v1/proyectos        Listar (paginado)
GET    /api/v1/proyectos/{id}   Obtener por ID
POST   /api/v1/proyectos        Crear
PATCH  /api/v1/proyectos/{id}   Actualizar
DELETE /api/v1/proyectos/{id}   Eliminar

TAREAS:
GET    /api/v1/tareas           Listar (paginado + filtros)
GET    /api/v1/tareas/{id}      Obtener por ID
POST   /api/v1/tareas           Crear
PATCH  /api/v1/tareas/{id}      Actualizar
DELETE /api/v1/tareas/{id}      Eliminar

FILTROS:
# ?completada=true/false
# ?prioridad=alta/media/baja
# ?proyecto_id=1
# ?buscar=texto
# ?pagina=1&por_pagina=10
""")

# %% [markdown]
# ---
#
# ## 4. Criterios de Evaluacion (100 pts)
#
# | Criterio | Puntos |
# |----------|--------|
# | Arquitectura | 25 |
# | Patrones | 20 |
# | Funcionalidad | 20 |
# | Calidad Codigo | 15 |
# | Testing | 10 |
# | Documentacion | 10 |

# %% [markdown]
# ---
#
# ## 5. Checklist Final
#
# - [ ] Repositorio GitHub
# - [ ] README con instrucciones
# - [ ] Coleccion Postman/Insomnia
# - [ ] Tests con cobertura > 70%
# - [ ] API funcional
# - [ ] Documentacion OpenAPI

# %% [markdown]
# ---
#
# **¡Exito en tu proyecto final!**
