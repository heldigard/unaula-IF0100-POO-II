# %% [markdown]
# # 📘 Clase 26: Proyecto Final + Cierre
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/unaula-IF0100-POO-II/blob/main/notebooks/unidad-03/clase-26-proyecto-final.ipynb)
#
# ## 🎯 Objetivos de la Clase
#
# Al finalizar esta clase, habras:
# - Integrado todos los conceptos del curso
# - Completado el proyecto TaskFlow
# - Aplicado mejores practicas de desarrollo
# - Preparado entrega final del proyecto
#
# ---
#
# ## 📋 Checklist del Proyecto TaskFlow
#
# ### ✅ Requisitos Funcionales
#
# | Modulo | Estado | Descripcion |
# |--------|--------|-------------|
# | Usuarios | ⬜ | Registro, login, perfiles |
# | Proyectos | ⬜ | CRUD de proyectos |
# | Tareas | ⬜ | CRUD de tareas con estados |
# | Autenticacion | ⬜ | JWT, permisos |
# | API REST | ⬜ | Endpoints documentados |
#
# ### ✅ Requisitos Tecnicos
#
# | Aspecto | Minimo Esperado |
# |---------|-----------------|(
# | Cobertura de tests | > 80% |
# | Documentacion API | OpenAPI/Swagger |
# | Codigo limpio | PEP 8, type hints |
# | Arquitectura | Clean Architecture / DDD |
# | Base de datos | PostgreSQL/SQLite |
#
# ---
#
# ## 🏗️ Arquitectura Final de TaskFlow

# %%
ARCHITECTURE_DIAGRAM = '''
┌─────────────────────────────────────────────────────────────┐
│                    PRESENTATION LAYER                        │
│  ┌─────────────────┐  ┌─────────────────┐                   │
│  │   FastAPI API   │  │   Templates     │                   │
│  │   (REST + JWT)  │  │   (Jinja2)      │                   │
│  └────────┬────────┘  └─────────────────┘                   │
└───────────┼─────────────────────────────────────────────────┘
            │
┌───────────▼─────────────────────────────────────────────────┐
│                   APPLICATION LAYER                         │
│  ┌─────────────────┐  ┌─────────────────┐                   │
│  │  Services       │  │  DTOs/Schemas   │                   │
│  │  (Casos de uso) │  │  (Pydantic)     │                   │
│  └────────┬────────┘  └─────────────────┘                   │
└───────────┼─────────────────────────────────────────────────┘
            │
┌───────────▼─────────────────────────────────────────────────┐
│                     DOMAIN LAYER                            │
│  ┌─────────────────┐  ┌─────────────────┐  ┌─────────────┐  │
│  │  Entities       │  │  Value Objects  │  │  Domain     │  │
│  │  (Models)       │  │  (Email, etc.)  │  │  Services   │  │
│  └─────────────────┘  └─────────────────┘  └─────────────┘  │
│  ┌─────────────────┐  ┌─────────────────┐                   │
│  │  Repositories   │  │  Aggregates     │                   │
│  │  (Interfaces)   │  │  (Proyecto)     │                   │
│  └─────────────────┘  └─────────────────┘                   │
└───────────┬─────────────────────────────────────────────────┘
            │
┌───────────▼─────────────────────────────────────────────────┐
│                 INFRASTRUCTURE LAYER                        │
│  ┌─────────────────┐  ┌─────────────────┐                   │
│  │  SQLAlchemy     │  │  Repositories   │                   │
│  │  (ORM)          │  │  (Impl.)        │                   │
│  └─────────────────┘  └─────────────────┘                   │
│  ┌─────────────────┐  ┌─────────────────┐                   │
│  │  PostgreSQL     │  │  Migrations     │                   │
│  │  (Database)     │  │  (Alembic)      │                   │
│  └─────────────────┘  └─────────────────┘                   │
└─────────────────────────────────────────────────────────────┘
'''

print(ARCHITECTURE_DIAGRAM)

# %% [markdown]
# ---
#
# ## 📚 Guia de Entrega

# %% [markdown]
# ### Estructura del Repositorio
#
# ```
# IF0100-POO-II/
# ├── README.md                 # Documentacion del proyecto
# ├── requirements.txt          # Dependencias
# ├── .env.example             # Variables de entorno de ejemplo
# ├── pytest.ini              # Configuracion de tests
# │
# ├── src/taskflow/            # Codigo fuente
# │   ├── __init__.py
# │   ├── main.py             # Entry point
# │   ├── config.py           # Configuracion
# │   ├── database.py         # Conexion a BD
# │   │
# │   ├── domain/             # Capa de dominio (DDD)
# │   │   ├── models/         # Entidades
# │   │   ├── repositories/   # Interfaces
# │   │   └── services/       # Servicios de dominio
# │   │
# │   ├── application/        # Capa de aplicacion
# │   │   ├── schemas/        # DTOs Pydantic
# │   │   └── services/       # Casos de uso
# │   │
# │   ├── infrastructure/     # Capa de infraestructura
# │   │   └── repositories/   # Implementaciones
# │   │
# │   └── api/                # Capa de presentacion
# │       ├── dependencies.py # Inyeccion de dependencias
# │       └── routes/         # Routers FastAPI
# │
# ├── tests/                   # Tests
# │   ├── conftest.py         # Fixtures
# │   ├── test_domain/
# │   ├── test_api/
# │   └── test_integration/
# │
# └── docs/                    # Documentacion adicional
#     └── api.md
# ```
#
# ### README.md Requerido
#
# Tu README debe incluir:
# 1. **Descripcion**: Que hace el proyecto
# 2. **Instalacion**: Pasos para correr localmente
# 3. **Uso**: Ejemplos de la API
# 4. **Testing**: Como ejecutar tests
# 5. **Arquitectura**: Diagrama o explicacion
# 6. **Autores**: Integrantes del equipo

# %% [markdown]
# ---
#
# ## 🎯 Criterios de Evaluacion
#
# | Criterio | Peso | Descripcion |
# |----------|------|-------------|
# | Funcionalidad | 30% | Cumple todos los requisitos |
# | Codigo Limpio | 20% | PEP 8, nombres claros, organizacion |
# | Testing | 20% | Cobertura > 80%, tests significativos |
# | Arquitectura | 15% | Aplicacion de DDD, capas bien definidas |
# | Documentacion | 15% | README, docstrings, API docs |
#
# ---
#
# ## 🚀 Comandos para Entrega
#
# ```bash
# # 1. Ejecutar tests con cobertura
# pytest --cov=src/taskflow --cov-report=html
#
# # 2. Verificar formato del codigo
# black src/ tests/ --check
# flake8 src/ tests/
#
# # 3. Verificar tipos
# mypy src/
#
# # 4. Ejecutar servidor y probar
# uvicorn src.taskflow.main:app --reload
#
# # 5. Verificar documentacion
# # Abrir: http://localhost:8000/docs
# ```
#
# ---
#
# ## 🎓 Consejos Finales
#
# 1. **Empieza por los tests**: Siempre escribe tests primero
# 2. **Itera rapido**: No busques perfeccion desde el inicio
# 3. **Pide feedback**: Muestra avances al docente
# 4. **Documenta mientras codificas**: Es mas facil que al final
# 5. **Versiona todo**: Commit frecuente con mensajes claros
#
# ---
#
# ## 📖 Recursos Adicionales
#
# - [FastAPI Documentation](https://fastapi.tiangolo.com/)
# - [SQLAlchemy 2.0 Docs](https://docs.sqlalchemy.org/)
# - [Pydantic Docs](https://docs.pydantic.dev/)
# - [pytest Docs](https://docs.pytest.org/)
#
# ---
#
# **¡Felicitaciones por completar el curso IF0100 - POO II! 🎉**
#
# Ahora tienes las herramientas para construir aplicaciones profesionales con Python.
#
# **¡A codear se ha dicho! 💻**
