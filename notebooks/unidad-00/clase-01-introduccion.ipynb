# %% [markdown]
# # 📘 Clase 1: Introducción a Python y Configuración
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/unaula-IF0100-POO-II/blob/main/notebooks/unidad-00/clase-01-introduccion.ipynb)
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al finalizar esta clase, serás capaz de:
# - Comprender qué es Python y sus características principales
# - Configurar el entorno de desarrollo (VS Code + Python)
# - Ejecutar tu primer programa Python
# - Entender la diferencia entre intérprete y compilador
# - Conocer las mejores prácticas de código limpio
#
# ---
#
# ## 📚 Teoría: ¿Qué es Python?
#
# ### Características Principales
#
# - **Lenguaje interpretado**: No requiere compilación previa
# - **Tipado dinámico**: No necesitas declarar tipos explícitamente
# - **Sintaxis limpia**: Código legible y fácil de entender
# - **Multiplataforma**: Funciona en Windows, macOS y Linux
# - **Multiparadigma**: Soporta POO, programación funcional y procedural
#
# ### ¿Por qué Python para POO II?
#
# 1. **Sintaxis elegante** para conceptos de POO
# 2. **Ecosistema robusto** (FastAPI, SQLAlchemy, pytest)
# 3. **Comunidad activa** y documentación extensa
# 4. **Uso profesional** en backend, data science, IA
#
# ---
#
# ## 🛠️ Configuración del Entorno
#
# ### 1. Verificar Instalación de Python
#
# Abre una terminal y ejecuta:

# %%
# Verificar versión de Python
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# %% [markdown]
# ### 2. Tu Primer Programa: "Hola Mundo"
#
# La tradición de todo programador:

# %%
# Mi primer programa en Python
print("¡Hola, Mundo!")
print("Bienvenidos al curso IF0100 - POO II")

# %% [markdown]
# ### 3. Función `print()` - Más allá de lo básico

# %%
# Diferentes formas de usar print()
nombre = "Estudiante"
curso = "IF0100"

# Concatenación con +
print("Hola " + nombre + ", bienvenido a " + curso)

# Usando comas (agrega espacios automáticamente)
print("Hola", nombre, ", bienvenido a", curso)

# f-strings (recomendado en Python 3.6+)
print(f"Hola {nombre}, bienvenido a {curso}")

# .format()
print("Hola {}, bienvenido a {}".format(nombre, curso))

# Parámetros especiales
print("Línea 1", end=" ")  # No salta de línea
print("continúa aquí")

print("A", "B", "C", sep="-")  # Separador personalizado

# %% [markdown]
# ### 4. Función `input()` - Interactuar con el Usuario

# %%
# Nota: En Jupyter/Colab, input() abre un cuadro de diálogo
# Descomenta las siguientes líneas para probar:

# nombre_usuario = input("¿Cuál es tu nombre? ")
# print(f"¡Gusto en conocerte, {nombre_usuario}!")

# Simulación de input (para el notebook)
nombre_usuario = "Juan"  # Cambia este valor
print(f"Simulación: ¡Hola, {nombre_usuario}!")

# %% [markdown]
# ### 5. Comentarios en Python
#
# Los comentarios son esenciales para documentar tu código:

# %%
# Este es un comentario de una línea

"""
Este es un comentario
de múltiples líneas
usando triples comillas dobles
"""

'''
También puedes usar
comillas simples triples
para comentarios multilínea
'''

# Código con comentarios útiles
x = 10  # Inicializamos contador
# TODO: Implementar validación de entrada
# FIXME: Este código tiene un bug conocido
print(x)

# %% [markdown]
# ---
#
# ## 📝 Ejercicios Prácticos
#
# ### Ejercicio 1: Presentación Personal
# Crea un programa que imprima tu presentación personal con:
# - Nombre completo
# - Edad
# - Carrera
# - Por qué elegiste este curso

# %%
# Tu solución aquí
# Ejercicio 1: Presentación Personal

print("=== MI PRESENTACIÓN ===")
# Completa con tu información
nombre = ""
edad = 0
carrera = ""
motivacion = ""

# Imprime tu presentación usando f-strings
# print(f"...")

# %% [markdown]
# ### Ejercicio 2: Calculadora Simple
# Crea un programa que dados dos números, imprima:
# - La suma
# - La resta
# - La multiplicación
# - La división

# %%
# Tu solución aquí
# Ejercicio 2: Calculadora Simple

num1 = 15
num2 = 4

# Calcula e imprime los resultados
# suma = ...
# resta = ...
# multiplicacion = ...
# division = ...

# Usa print() para mostrar cada resultado con un mensaje descriptivo

# %% [markdown]
# ### Ejercicio 3: Arte ASCII
# Crea un programa que imprima una figura usando caracteres ASCII.

# %%
# Tu solución aquí
# Ejercicio 3: Arte ASCII

# Ejemplo: Dibuja un gato, una casa, o cualquier figura
# Puedes usar múltiples print() o un solo print() con \n
print("   /\_/\")
print("  ( o.o )")
print("   > ^ <")
print("  /|   |\\")
print(" (_|   |_)")

# Crea tu propia figura:

# %% [markdown]
# ---
#
# ## 🔗 Conexión con TaskFlow
#
# En el proyecto **TaskFlow** (Sistema de Gestión de Tareas), usamos Python como lenguaje principal.
#
# ### ¿Dónde aplicamos estos conceptos?
#
# 1. **Scripts de utilidad**: Scripts para inicializar la base de datos
# 2. **Logging**: Mensajes informativos con `print()` durante desarrollo
# 3. **CLI tools**: Herramientas de línea de comandos para administración
#
# ```python
# # Ejemplo: Script de verificación para TaskFlow
# print("=== Verificación del Sistema TaskFlow ===")
# print("✓ Python 3.11+ instalado")
# print("✓ Dependencias instaladas")
# print("✓ Base de datos configurada")
# print("✓ Servidor listo para iniciar")
# ```
#
# ---
#
# ## 📖 Recursos Adicionales
#
# - [Python Official Tutorial](https://docs.python.org/3/tutorial/)
# - [Google Colab Intro](https://colab.research.google.com/notebooks/intro.ipynb)
# - [VS Code Python Setup](https://code.visualstudio.com/docs/python/python-tutorial)
#
# ---
#
# **¡Felicitaciones! Has completado tu primera clase de Python. 🎉**
